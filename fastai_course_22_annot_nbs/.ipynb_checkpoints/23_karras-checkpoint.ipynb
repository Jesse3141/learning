# %% [markdown]
# # Karras pre-conditioning

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
! pip install k_diffusion
# Out:
# Collecting k_diffusion
#   Obtaining dependency information for k_diffusion from https://files.pythonhosted.org/packages/38/6e/fe37fc3b01b86836ee4d0b11a8097eaef5e388d9e2f76c4958e24ef15611/k_diffusion-0.1.1.post1-py3-none-any.whl.metadata
#   Downloading k_diffusion-0.1.1.post1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: accelerate in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (0.29.2)
# Collecting clean-fid (from k_diffusion)
#   Obtaining dependency information for clean-fid from https://files.pythonhosted.org/packages/70/56/0dfc83e0fe455cfe6272b23a65039b4101c63a4e7446801e26178b675fbf/clean_fid-0.1.35-py3-none-any.whl.metadata
#   Downloading clean_fid-0.1.35-py3-none-any.whl.metadata (36 kB)
# Collecting clip-anytorch (from k_diffusion)
#   Obtaining dependency information for clip-anytorch from https://files.pythonhosted.org/packages/88/14/19d5ff584cb58f654d22d8d6552d7c2fff7b85e4a9d525357f62a4d1e7e0/clip_anytorch-2.6.0-py3-none-any.whl.metadata
#   Downloading clip_anytorch-2.6.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting dctorch (from k_diffusion)
#   Obtaining dependency information for dctorch from https://files.pythonhosted.org/packages/cd/47/61b627404c2d6f31dcbc491ff83da1f4336c7ae7893cfdc6c52db490ec59/dctorch-0.1.2-py3-none-any.whl.metadata
#   Downloading dctorch-0.1.2-py3-none-any.whl.metadata (607 bytes)
# Requirement already satisfied: einops in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (0.7.0)
# Collecting jsonmerge (from k_diffusion)
#   Obtaining dependency information for jsonmerge from https://files.pythonhosted.org/packages/71/c2/1032d0dbc2152c45f3d1e582a72e68f41898de9665202392d9400dfa329d/jsonmerge-1.9.2-py3-none-any.whl.metadata
#   Downloading jsonmerge-1.9.2-py3-none-any.whl.metadata (21 kB)
# Collecting kornia (from k_diffusion)
#   Obtaining dependency information for kornia from https://files.pythonhosted.org/packages/ac/fa/5612c4b1ad83b3044062e9dd0ca3c91937d8023cff0836269e18573655b0/kornia-0.7.2-py2.py3-none-any.whl.metadata
#   Downloading kornia-0.7.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Pillow in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (10.2.0)
# Requirement already satisfied: safetensors in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (0.4.2)
# Collecting scikit-image (from k_diffusion)
#   Obtaining dependency information for scikit-image from https://files.pythonhosted.org/packages/ae/a4/1143ab15a5a142ee31624da80744d13f67fd0cff801062cd271a2f1b10e4/scikit_image-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_image-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: scipy in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (1.13.0)
# Requirement already satisfied: torch>=2.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (2.0.1)
# Collecting torchdiffeq (from k_diffusion)
#   Obtaining dependency information for torchdiffeq from https://files.pythonhosted.org/packages/2c/9b/b9c3e17f261e30f630511390e0dd33fc529073f1f2db222a1f09dc49a1ae/torchdiffeq-0.2.3-py3-none-any.whl.metadata
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl.metadata (488 bytes)
# Collecting torchsde (from k_diffusion)
#   Obtaining dependency information for torchsde from https://files.pythonhosted.org/packages/dd/1f/b67ebd7e19ffe259f05d3cf4547326725c3113d640c277030be3e9998d6f/torchsde-0.2.6-py3-none-any.whl.metadata
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torchvision in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (0.15.2)
# Requirement already satisfied: tqdm in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from k_diffusion) (4.66.1)
# Collecting wandb (from k_diffusion)
#   Obtaining dependency information for wandb from https://files.pythonhosted.org/packages/8b/8d/bb05a4ecdeac6b2256d98ac10bae8723af5d7a8c1a4c2384b3ae0f80370e/wandb-0.16.6-py3-none-any.whl.metadata
#   Downloading wandb-0.16.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (4.9.0)
# Requirement already satisfied: sympy in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (1.12)
# Requirement already satisfied: networkx in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (3.2.1)
# Requirement already satisfied: jinja2 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from torch>=2.0->k_diffusion) (2.0.0)
# Requirement already satisfied: setuptools in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=2.0->k_diffusion) (68.2.0)
# Requirement already satisfied: wheel in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=2.0->k_diffusion) (0.41.2)
# Requirement already satisfied: cmake in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from triton==2.0.0->torch>=2.0->k_diffusion) (3.28.1)
# Requirement already satisfied: lit in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from triton==2.0.0->torch>=2.0->k_diffusion) (17.0.6)
# Requirement already satisfied: numpy>=1.17 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from accelerate->k_diffusion) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from accelerate->k_diffusion) (23.2)
# Requirement already satisfied: psutil in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from accelerate->k_diffusion) (5.9.8)
# Requirement already satisfied: pyyaml in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from accelerate->k_diffusion) (6.0.1)
# Requirement already satisfied: huggingface-hub in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from accelerate->k_diffusion) (0.20.3)
# Requirement already satisfied: requests in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from clean-fid->k_diffusion) (2.31.0)
# Collecting ftfy (from clip-anytorch->k_diffusion)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/f4/f0/21efef51304172736b823689aaf82f33dbc64f54e9b046b75f5212d5cee7/ftfy-6.2.0-py3-none-any.whl.metadata
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from clip-anytorch->k_diffusion) (2023.12.25)
# Requirement already satisfied: jsonschema>2.4.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from jsonmerge->k_diffusion) (4.21.1)
# Collecting kornia-rs>=0.1.0 (from kornia->k_diffusion)
#   Obtaining dependency information for kornia-rs>=0.1.0 from https://files.pythonhosted.org/packages/48/0d/665f7402f6b76ca345e257520567039a1b4e40fdca27ba4927407bbf273a/kornia_rs-0.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading kornia_rs-0.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Collecting imageio>=2.33 (from scikit-image->k_diffusion)
#   Obtaining dependency information for imageio>=2.33 from https://files.pythonhosted.org/packages/02/25/66533a8390e3763cf8254dee143dbf8a830391ea60d2762512ba7f9ddfbe/imageio-2.34.0-py3-none-any.whl.metadata
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->k_diffusion)
#   Obtaining dependency information for tifffile>=2022.8.12 from https://files.pythonhosted.org/packages/cd/0b/33610b4d0d1bb83a6bfd20ed838f52e02a44e9b439116cd4f3d424e81a80/tifffile-2024.2.12-py3-none-any.whl.metadata
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->k_diffusion)
#   Obtaining dependency information for lazy-loader>=0.4 from https://files.pythonhosted.org/packages/83/60/d497a310bde3f01cb805196ac61b7ad6dc5dcf8dce66634dc34364b20b4f/lazy_loader-0.4-py3-none-any.whl.metadata
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting trampoline>=0.1.2 (from torchsde->k_diffusion)
#   Obtaining dependency information for trampoline>=0.1.2 from https://files.pythonhosted.org/packages/73/54/d2805324fb746d8da86d3844bee4f55c0cfd6c136de61b713772d44c5bea/trampoline-0.1.2-py3-none-any.whl.metadata
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from wandb->k_diffusion) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->k_diffusion)
#   Obtaining dependency information for GitPython!=3.1.29,>=1.0.0 from https://files.pythonhosted.org/packages/e9/bd/cc3a402a6439c15c3d4294333e13042b915bbeab54edc457c723931fed3f/GitPython-3.1.43-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting sentry-sdk>=1.0.0 (from wandb->k_diffusion)
#   Obtaining dependency information for sentry-sdk>=1.0.0 from https://files.pythonhosted.org/packages/b7/26/cf87e98fb7fa5781c40474970a76d40b04289b949c0a327b719336aa5bca/sentry_sdk-1.45.0-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-1.45.0-py2.py3-none-any.whl.metadata (9.9 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb->k_diffusion)
#   Obtaining dependency information for docker-pycreds>=0.4.0 from https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting setproctitle (from wandb->k_diffusion)
#   Obtaining dependency information for setproctitle from https://files.pythonhosted.org/packages/79/e7/54b36be02aee8ad573be68f6f46fd62838735c2f007b22df50eb5e13a20d/setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Collecting appdirs>=1.4.3 (from wandb->k_diffusion)
#   Obtaining dependency information for appdirs>=1.4.3 from https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl.metadata
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb->k_diffusion)
#   Obtaining dependency information for protobuf!=4.21.0,<5,>=3.19.0 from https://files.pythonhosted.org/packages/15/db/7f731524fe0e56c6b2eb57d05b55d3badd80ef7d1f1ed59db191b2fdd8ab/protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.4.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb->k_diffusion) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->k_diffusion)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from jsonschema>2.4.0->jsonmerge->k_diffusion) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from jsonschema>2.4.0->jsonmerge->k_diffusion) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from jsonschema>2.4.0->jsonmerge->k_diffusion) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from jsonschema>2.4.0->jsonmerge->k_diffusion) (0.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from requests->clean-fid->k_diffusion) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from requests->clean-fid->k_diffusion) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from requests->clean-fid->k_diffusion) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from requests->clean-fid->k_diffusion) (2023.11.17)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from ftfy->clip-anytorch->k_diffusion) (0.2.13)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from huggingface-hub->accelerate->k_diffusion) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from jinja2->torch>=2.0->k_diffusion) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /home/jesse/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages (from sympy->torch>=2.0->k_diffusion) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->k_diffusion)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading k_diffusion-0.1.1.post1-py3-none-any.whl (33 kB)
# Downloading clean_fid-0.1.35-py3-none-any.whl (26 kB)
# Downloading clip_anytorch-2.6.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.4 MB/s eta 0:00:000:00:010:00:01:01
# Downloading dctorch-0.1.2-py3-none-any.whl (2.3 kB)
# Downloading jsonmerge-1.9.2-py3-none-any.whl (19 kB)
# Downloading kornia-0.7.2-py2.py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading scikit_image-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.0 MB/s eta 0:00:00
# Downloading wandb-0.16.6-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.1 MB/s eta 0:00:002.7 MB/s eta 0:00:01
# Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 2.0 MB/s eta 0:00:0031m2.3 MB/s eta 0:00:01
# Downloading kornia_rs-0.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 2.2 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Downloading sentry_sdk-1.45.0-py2.py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 2.2 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 1.7 MB/s eta 0:00:002.7 MB/s eta 0:00:01
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 1.7 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.7 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: trampoline, appdirs, tifffile, smmap, setproctitle, sentry-sdk, protobuf, lazy-loader, kornia-rs, imageio, ftfy, docker-pycreds, scikit-image, gitdb, GitPython, wandb, jsonmerge, torchsde, torchdiffeq, kornia, dctorch, clip-anytorch, clean-fid, k_diffusion
# Successfully installed GitPython-3.1.43 appdirs-1.4.4 clean-fid-0.1.35 clip-anytorch-2.6.0 dctorch-0.1.2 docker-pycreds-0.4.0 ftfy-6.2.0 gitdb-4.0.11 imageio-2.34.0 jsonmerge-1.9.2 k_diffusion-0.1.1.post1 kornia-0.7.2 kornia-rs-0.1.3 lazy-loader-0.4 protobuf-4.25.3 scikit-image-0.23.1 sentry-sdk-1.45.0 setproctitle-1.3.3 smmap-5.0.1 tifffile-2024.2.12 torchdiffeq-0.2.3 torchsde-0.2.6 trampoline-0.1.2 wandb-0.16.6
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import timm, torch, random, datasets, math, fastcore.all as fc, numpy as np, matplotlib as mpl, matplotlib.pyplot as plt
import k_diffusion as K, torchvision.transforms as T
import torchvision.transforms.functional as TF,torch.nn.functional as F

from torch.utils.data import DataLoader,default_collate
from pathlib import Path
from torch.nn import init
from fastcore.foundation import L
from torch import nn,tensor
from datasets import load_dataset
from operator import itemgetter
from torcheval.metrics import MulticlassAccuracy
from functools import partial
from torch.optim import lr_scheduler
from torch import optim

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *
from miniai.sgd import *
from miniai.resnet import *
from miniai.augment import *
from miniai.accel import *

# %%
from fastprogress import progress_bar
from diffusers import UNet2DModel, DDIMPipeline, DDPMPipeline, DDIMScheduler, DDPMScheduler

# %%
torch.set_printoptions(precision=5, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

import logging
logging.disable(logging.WARNING)

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
xl,yl = 'image','label'
name = "fashion_mnist"
n_steps = 1000
bs = 512
dsd = load_dataset(name)

# %%
@inplace
def transformi(b): b[xl] = [F.pad(TF.to_tensor(o), (2,2,2,2))*2-1 for o in b[xl]]

tds = dsd.with_transform(transformi)
dls = DataLoaders.from_dd(tds, bs)

dl = dls.train
xb,yb = b = next(iter(dl))

# %%
# sig_data = xb.std()
sig_data = 0.66

# %% [markdown]
# `y` is clean signal, `n` is `N(0,1)` noise.
#
# ![image.png](attachment:image.png)

# %%
def scalings(sig):
    totvar = sig**2+sig_data**2
    # c_skip,c_out,c_in
    return sig_data**2/totvar,sig*sig_data/totvar.sqrt(),1/totvar.sqrt()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sig_samp = (torch.randn([10000])*1.2-1.2).exp()

# %%
plt.hist(sig_samp);

# %%
import seaborn as sns

# %%
sns.kdeplot(sig_samp, clip=(0,10));

# %%
def noisify(x0):
    device = x0.device
    sig = (torch.randn([len(x0)])*1.2-1.2).exp().to(x0).reshape(-1,1,1,1)
    noise = torch.randn_like(x0, device=device)
    c_skip,c_out,c_in = scalings(sig)
    noised_input = x0 + noise*sig
    target = (x0-c_skip*noised_input)/c_out
    return (noised_input*c_in,sig.squeeze()),target

# %%
def collate_ddpm(b): return noisify(default_collate(b)[xl])
def dl_ddpm(ds): return DataLoader(ds, batch_size=bs, collate_fn=collate_ddpm, num_workers=8)

# %%
dls = DataLoaders(dl_ddpm(tds['train']), dl_ddpm(tds['test']))

# %%
dl = dls.train
(noised_input,sig),target = b = next(iter(dl))

# %%
show_images(noised_input[:25], imsize=1.5, titles=fc.map_ex(sig[:25], '{:.02f}'))

# %%
show_images(target[:25], imsize=1.5, titles=fc.map_ex(sig[:25], '{:.02f}'))

# %%
noised_input.mean(),noised_input.std(),target.mean(),target.std()
# Out:
# (tensor(-0.69019), tensor(1.01665), tensor(-0.40007), tensor(1.03293))

# %% [markdown]
# ## Train

# %%
clean_mem()

# %%
class UNet(UNet2DModel):
    def forward(self, x): return super().forward(*x).sample

# %%
def init_ddpm(model):
    for o in model.down_blocks:
        for p in o.resnets:
            p.conv2.weight.data.zero_()
            for p in fc.L(o.downsamplers): init.orthogonal_(p.conv.weight)

    for o in model.up_blocks:
        for p in o.resnets: p.conv2.weight.data.zero_()

    model.conv_out.weight.data.zero_()

# %%
astats = ActivationStats(fc.risinstance(nn.ReLU))

# %%
lr = 1e-2
epochs = 1
opt_func = partial(optim.Adam, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
cbs = [DeviceCB(), MixedPrecision(), ProgressCB(plot=True), MetricsCB(), BatchSchedCB(sched)]
model = UNet(in_channels=1, out_channels=1, block_out_channels=(32, 64, 128, 256), norm_num_groups=8)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>nan</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>nan</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
astats.plot_stats()

# %%
# torch.save(learn.model, 'models/fashion_karras.pkl')
model = learn.model = torch.load('models/fashion_karras.pkl').cuda()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 # torch.save(learn.model, 'models/fashion_karras.pkl')
# ----> 2 model = learn.model = torch.load('models/fashion_karras.pkl').cuda()
#
# File ~/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages/torch/serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# File ~/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages/torch/serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# File ~/lab/fastai/course22p2/fastai2022/.venv/lib/python3.10/site-packages/torch/serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/fashion_karras.pkl'

# %%
def denoise(target, noised_input): return target*c_out + noised_input*c_skip

# %%
with torch.no_grad():
    sigr = sig.cuda().reshape(-1,1,1,1)
    c_skip,c_out,c_in = scalings(sigr)
    targ_pred = learn.model((noised_input.cuda(),sig.cuda()))
    x0_pred = denoise(targ_pred, noised_input.cuda()/c_in)

# %%
show_images(noised_input[:25], imsize=1.5, titles=fc.map_ex(sig[:25], '{:.02f}'))

# %%
show_images(x0_pred[:25].clamp(-1,1), imsize=1.5, titles=fc.map_ex(sig[:25], '{:.02f}'))

# %%
show_images(denoise(target.cuda(), noised_input.cuda()/c_in)[:25], imsize=1.5, titles=fc.map_ex(sig[:25], '{:.02f}'))

# %%
sig_r = tensor(80.).cuda().reshape(-1,1,1,1)
c_skip,c_out,c_in = scalings(sig_r)
x_r = torch.randn(32,1,32,32).to(model.device)*sig_r
with torch.no_grad():
    targ_pred = learn.model((x_r*c_in,sig_r.squeeze()))
    x0_pred = denoise(targ_pred, x_r)
show_images(x0_pred[:25], imsize=1.5)

# %%
x0_pred.max(),x0_pred.min(),x0_pred.mean(),x0_pred.std()
# Out:
# (tensor(0.63882, device='cuda:0'),
#  tensor(-1.18548, device='cuda:0'),
#  tensor(-0.54164, device='cuda:0'),
#  tensor(0.43493, device='cuda:0'))

# %% [markdown]
# ## Sampling

# %%
from miniai.fid import ImageEval

# %%
cmodel = torch.load('models/data_aug2.pkl')
del(cmodel[8])
del(cmodel[7])

bs = 2048
tds = dsd.with_transform(transformi)
dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)

dt = dls.train
xb,yb = next(iter(dt))

ie = ImageEval(cmodel, dls, cbs=[DeviceCB()])

# %%
sz = (512,1,32,32)

# %%
sz = (2048,1,32,32)

# %%
def sigmas_karras(n, sigma_min=0.01, sigma_max=80., rho=7., device='cpu'):
    ramp = torch.linspace(0, 1, n)
    min_inv_rho = sigma_min**(1/rho)
    max_inv_rho = sigma_max**(1/rho)
    sigmas = (max_inv_rho + ramp * (min_inv_rho-max_inv_rho))**rho
    return torch.cat([sigmas, tensor([0.])]).to(device)

# %%
sk = sigmas_karras(100)
plt.plot(sk);

# %%
def denoise(model, x, sig):
    c_skip,c_out,c_in = scalings(sig)
    return model((x*c_in, sig))*c_out + x*c_skip

# %%
def get_ancestral_step(sigma_from, sigma_to, eta=1.):
    if not eta: return sigma_to, 0.
    var_to,var_from = sigma_to**2,sigma_from**2
    sigma_up = min(sigma_to, eta * (var_to * (var_from-var_to)/var_from)**0.5)
    return (var_to-sigma_up**2)**0.5, sigma_up

# %%
@torch.no_grad()
def sample_euler_ancestral(x, sigs, i, model, eta=1.):
    sig,sig2 = sigs[i],sigs[i+1]
    denoised = denoise(model, x, sig)
    sigma_down,sigma_up = get_ancestral_step(sig, sig2, eta=eta)
    x = x + (x-denoised)/sig*(sigma_down-sig)
    return x + torch.randn_like(x)*sigma_up

# %%
@torch.no_grad()
def sample_euler(x, sigs, i, model):
    sig,sig2 = sigs[i],sigs[i+1]
    denoised = denoise(model, x, sig)
    return x + (x-denoised)/sig*(sig2-sig)

# %%
@torch.no_grad()
def sample_heun(x, sigs, i, model, s_churn=0., s_tmin=0., s_tmax=float('inf'), s_noise=1.):
    sig,sig2 = sigs[i],sigs[i+1]
    n = len(sigs)
    gamma = min(s_churn/(n-1), 2**0.5-1) if s_tmin<=sig<=s_tmax else 0.
    eps = torch.randn_like(x) * s_noise
    sigma_hat = sig * (gamma+1)
    if gamma > 0: x = x + eps * (sigma_hat**2-sig**2)**0.5
    denoised = denoise(model, x, sig)
    d = (x-denoised)/sig
    dt = sig2-sigma_hat
    x_2 = x + d*dt
    if sig2==0: return x_2
    denoised_2 = denoise(model, x_2, sig2)
    d_2 = (x_2-denoised_2)/sig2
    d_prime = (d+d_2)/2
    return x + d_prime*dt

# %%
def sample(sampler, model, steps=100, sigma_max=80., **kwargs):
    preds = []
    x = torch.randn(sz).to(model.device)*sigma_max
    sigs = sigmas_karras(steps, device=model.device, sigma_max=sigma_max)
    for i in progress_bar(range(len(sigs)-1)):
        x = sampler(x, sigs, i, model, **kwargs)
        preds.append(x)
    return preds

# %%
# preds = sample_lms(model, steps=20, order=3)
# preds = sample(sample_euler_ancestral, model, steps=100, eta=0.5)
preds = sample(sample_euler, model, steps=100)
# preds = sample(sample_heun, model, steps=20, s_churn=0.5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 00:09<00:00]
#     </div>

# %%
s = preds[-1]
s.min(),s.max()
# Out:
# (tensor(-1.08955, device='cuda:0'), tensor(1.46819, device='cuda:0'))

# %%
show_images(s[:25].clamp(-1,1), imsize=1.5)

# %%
# euler 100
ie.fid(s),ie.kid(s),s.shape
# Out:
# (5.231043207481207, 0.0031656520441174507, torch.Size([2048, 1, 32, 32]))

# %%
# euler 100
ie.fid(s),ie.kid(s),s.shape
# Out:
# (5.406003616592329, 0.015411057509481907, torch.Size([2048, 1, 32, 32]))

# %%
# ancestral 100 0.5
ie.fid(s),ie.kid(s),s.shape
# Out:
# (5.452807558586642, 0.0071729626506567, torch.Size([2048, 1, 32, 32]))

# %%
# heun 50
ie.fid(s),ie.kid(s),s.shape
# Out:
# (6.221842673288506, 0.023713070899248123, torch.Size([2048, 1, 32, 32]))

# %%
# heun 20
ie.fid(s),ie.kid(s),s.shape
# Out:
# (5.610681075267394, -0.005569742992520332, torch.Size([2048, 1, 32, 32]))

# %%
# heun 20, churn 0.5
ie.fid(s),ie.kid(s),s.shape
# Out:
# (5.2517917311790825, 0.026914160698652267, torch.Size([2048, 1, 32, 32]))

# %%
# lms 20
ie.fid(s),ie.kid(s),s.shape
# Out:
# (5.061003587997561, 0.019381564110517502, torch.Size([2048, 1, 32, 32]))

# %%
# reals
ie.fid(xb)
# Out:
# 2.5736580178430586

# %%
from scipy import integrate

# %%
def linear_multistep_coeff(order, t, i, j):
    if order-1 > i: raise ValueError(f'Order {order} too high for step {i}')
    def fn(tau):
        prod = 1.
        for k in range(order):
            if j == k: continue
            prod *= (tau-t[i-k]) / (t[i-j]-t[i-k])
        return prod
    return integrate.quad(fn, t[i], t[i+1], epsrel=1e-4)[0]

# %%
@torch.no_grad()
def sample_lms(model, steps=100, order=4, sigma_max=80.):
    preds = []
    x = torch.randn(sz).to(model.device)*sigma_max
    sigs = sigmas_karras(steps, device=model.device, sigma_max=sigma_max)
    ds = []
    for i in progress_bar(range(len(sigs)-1)):
        sig = sigs[i]
        denoised = denoise(model, x, sig)
        d = (x-denoised)/sig
        ds.append(d)
        if len(ds) > order: ds.pop(0)
        cur_order = min(i+1, order)
        coeffs = [linear_multistep_coeff(cur_order, sigs, i, j) for j in range(cur_order)]
        x = x + sum(coeff*d for coeff, d in zip(coeffs, reversed(ds)))
        preds.append(x)
    return preds
