# %%
#|default_exp sgd

# %% [markdown]
# # Accelerated SGD

# %%
#|export
import torch

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *

# %%
import pickle,gzip,math,os,time,shutil,torch,matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
import fastcore.all as fc
from collections.abc import Mapping
from pathlib import Path
from operator import attrgetter,itemgetter
from functools import partial
from copy import copy
from contextlib import contextmanager

import torchvision.transforms.functional as TF,torch.nn.functional as F
from torch import tensor,nn,optim
from torch.utils.data import DataLoader,default_collate
from torch.nn import init
from torch.optim import lr_scheduler
from torcheval.metrics import MulticlassAccuracy
from datasets import load_dataset,load_dataset_builder

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *

# %%
from fastcore.test import test_close

torch.set_printoptions(precision=2, linewidth=140, sci_mode=False)
torch.manual_seed(1)

import logging
logging.disable(logging.WARNING)

set_seed(42)

# %%
xl,yl = 'image','label'
name = "fashion_mnist"
dsd = load_dataset(name)

bs = 1024
xmean,xstd = 0.28, 0.35

@inplace
def transformi(b): b[xl] = [(TF.to_tensor(o)-xmean)/xstd for o in b[xl]]

tds = dsd.with_transform(transformi)
dls = DataLoaders.from_dd(tds, bs, num_workers=4)

# %%
metrics = MetricsCB(accuracy=MulticlassAccuracy())
astats = ActivationStats(fc.risinstance(GeneralRelu))
cbs = [DeviceCB(), metrics, ProgressCB(plot=True), astats]
act_gr = partial(GeneralRelu, leak=0.1, sub=0.4)
iw = partial(init_weights, leaky=0.1)
lrf_cbs = [DeviceCB(), LRFinderCB()]

# %% [markdown]
# ## Optimizers

# %% [markdown]
# ### SGD

# %%
import ipdb
class SGD:
    def __init__(self, params, lr, wd=0.):
        params = list(params)
        fc.store_attr()
        self.i = 0

    def step(self):
        with torch.no_grad():
            for p in self.params:
                #ipdb.set_trace()
                self.reg_step(p)
                self.opt_step(p)
        self.i +=1
        
    def reg_step(self, p):
        # weight.grad += wd*weight
        if self.wd != 0: p *= 1 - self.lr*self.wd
    def opt_step(self, p): p -= p.grad * self.lr


    def zero_grad(self):
        for p in self.params: p.grad.data.zero_()

# %%
set_seed(42)
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=0.4, cbs=cbs, opt_func=SGD)

# %%
learn.fit(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.772</td>
#       <td>0.640</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.825</td>
#       <td>0.477</td>
# ...

# %% [markdown]
# Consider the difference between *weight decay* and *L2 regularization*:
#
# ``` python
# weight -= lr*wd*weight
# ```
#
# ...vs...
#
# ``` python
# weight.grad += wd*weight
# ```

# %% [markdown]
# ### Momentum

# %%
xs = torch.linspace(-4, 4, 100)
ys = 1 - (xs/3) ** 2 + torch.randn(100) * 0.1

# %%
_,axs = plt.subplots(2,2, figsize=(12,8))
betas = [0.5,0.7,0.9,0.99]
for beta,ax in zip(betas, axs.flatten()):
    ax.scatter(xs,ys)
    avg,res = 0,[]
    for yi in ys:
        avg = beta*avg + (1-beta)*yi
        res.append(avg)
    ax.plot(xs,np.array(res), color='red');
    ax.set_title(f'beta={beta}')

# %%
class Momentum(SGD):
    def __init__(self, params, lr, wd=0., mom=0.9):
        super().__init__(params, lr=lr, wd=wd)
        self.mom=mom

    def opt_step(self, p):
        if not hasattr(p, 'grad_avg'): p.grad_avg = torch.zeros_like(p.grad)
        p.grad_avg = p.grad_avg*self.mom + p.grad*(1-self.mom)
        p -= self.lr * p.grad_avg

# %%
set_seed(42)
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=1.5, cbs=cbs, opt_func=Momentum)

# %%
learn.fit(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.786</td>
#       <td>0.597</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.847</td>
#       <td>0.415</td>
# ...

# %%
astats.color_dim()

# %% [markdown]
# ### RMSProp

# %%
class RMSProp(SGD):
    def __init__(self, params, lr, wd=0., sqr_mom=0.99, eps=1e-5):
        super().__init__(params, lr=lr, wd=wd)
        self.sqr_mom,self.eps = sqr_mom,eps

    def opt_step(self, p):
        if not hasattr(p, 'sqr_avg'): p.sqr_avg = p.grad**2
        p.sqr_avg = p.sqr_avg*self.sqr_mom + p.grad**2*(1-self.sqr_mom)
        p -= self.lr * p.grad/(p.sqr_avg.sqrt() + self.eps)

# %%
set_seed(42)
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=3e-3, cbs=cbs, opt_func=RMSProp)
learn.fit(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.765</td>
#       <td>0.665</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.822</td>
#       <td>0.482</td>
# ...

# %%
astats.color_dim()

# %% [markdown]
# ### Adam

# %%
class Adam(SGD):
    def __init__(self, params, lr, wd=0., beta1=0.9, beta2=0.99, eps=1e-5):
        super().__init__(params, lr=lr, wd=wd)
        self.beta1,self.beta2,self.eps = beta1,beta2,eps

    def opt_step(self, p):
        if not hasattr(p, 'avg'): p.avg = torch.zeros_like(p.grad.data)
        if not hasattr(p, 'sqr_avg'): p.sqr_avg = torch.zeros_like(p.grad.data)
        p.avg = self.beta1*p.avg + (1-self.beta1)*p.grad
        unbias_avg = p.avg / (1 - (self.beta1**(self.i+1)))
        p.sqr_avg = self.beta2*p.sqr_avg + (1-self.beta2)*(p.grad**2)
        unbias_sqr_avg = p.sqr_avg / (1 - (self.beta2**(self.i+1)))
        p -= self.lr * unbias_avg / (unbias_sqr_avg + self.eps).sqrt()

# %%
set_seed(42)
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=6e-3, cbs=cbs, opt_func=Adam)
learn.fit(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.792</td>
#       <td>0.583</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.840</td>
#       <td>0.429</td>
# ...

# %% [markdown]
# ## Schedulers

# %% [markdown]
# We've already seen how we can easily write a custom LR-adjusting callback or `Learner`, or can use the predefined PyTorch schedulers. We'll use the predefined ones for now since there's nothing new to learn in implementing them ourselves.

# %%
' '.join(o for o in dir(lr_scheduler) if o[0].isupper() and o[1].islower())
# Out:
# 'ChainedScheduler ConstantLR CosineAnnealingLR CosineAnnealingWarmRestarts Counter CyclicLR ExponentialLR LambdaLR LinearLR MultiStepLR MultiplicativeLR OneCycleLR Optimizer PolynomialLR ReduceLROnPlateau SequentialLR StepLR'

# %%
' '.join(filter(lambda x: x[0].isupper() and x[1].islower(), dir(lr_scheduler)))
# Out:
# 'ChainedScheduler ConstantLR CosineAnnealingLR CosineAnnealingWarmRestarts Counter CyclicLR ExponentialLR LambdaLR LinearLR MultiStepLR MultiplicativeLR OneCycleLR Optimizer PolynomialLR ReduceLROnPlateau SequentialLR StepLR'

# %%
learn = TrainLearner(get_model(), dls, F.cross_entropy, lr=6e-3, cbs=[DeviceCB(), SingleBatchCB()])
learn.fit(1)

# %%
??TrainLearner
# Out:
# Init signature:
# TrainLearner(
#     model,
#     dls=(0,),
#     loss_func=<function mse_loss at 0x7359e3b0cd30>,
#     lr=0.1,
#     cbs=None,
#     opt_func=<class 'torch.optim.sgd.SGD'>,
# )
# Docstring:      <no docstring>
# Source:
# class TrainLearner(Learner):
#     def predict(self): self.preds = self.model(self.batch[0])
#     def get_loss(self): self.loss = self.loss_func(self.preds, self.batch[1])
#     def backward(self): self.loss.backward()
#     def step(self): self.opt.step()
#     def zero_grad(self): self.opt.zero_grad()
# File:           ~/lab/fastai/course22p2/fastai2022/nbs/miniai/learner.py
# Type:           type
# Subclasses:     MomentumLearner

# %%
opt = learn.opt
' '.join(o for o in dir(opt) if o[0]!='_')
# Out:
# 'add_param_group defaults load_state_dict param_groups profile_hook_step register_step_post_hook register_step_pre_hook state state_dict step zero_grad'

# %%
opt
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     lr: 0.006
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %%
param = next(iter(learn.model.parameters()))
st = opt.state[param]
len(opt.state.keys())
# Out:
# 10

# %%
opt.state.values()
# Out:
# dict_values([{'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}, {'momentum_buffer': None}])

# %%
st
# Out:
# {'momentum_buffer': None}

# %%
len(opt.param_groups)
# Out:
# 1

# %%
pg = opt.param_groups[0]

# %%
list(pg)
# Out:
# ['params',
#  'lr',
#  'momentum',
#  'dampening',
#  'weight_decay',
#  'nesterov',
#  'maximize',
#  'foreach',
#  'differentiable']

# %%
sched = lr_scheduler.CosineAnnealingLR(opt, 100)

# %%
sched.base_lrs
# Out:
# [0.006]

# %%
sched.get_last_lr()
# Out:
# [0.006]

# %%
def sched_lrs(sched, steps):
    lrs = [sched.get_last_lr()]
    for i in range(steps):
        sched.optimizer.step()
        sched.step()
        lrs.append(sched.get_last_lr())
    plt.plot(lrs)

# %%
sched_lrs(sched, 110)

# %% [markdown]
# ### Scheduler callbacks

# %%
#|export
class BaseSchedCB(Callback):
    def __init__(self, sched): self.sched = sched
    def before_fit(self, learn): 
        self.schedo = self.sched(learn.opt)
    def _step(self, learn):
        if learn.training: self.schedo.step()

# %%
#|export
class BatchSchedCB(BaseSchedCB):
    def after_batch(self, learn): 
        self._step(learn)

# %%
#|export
class HasLearnCB(Callback):
    def before_fit(self, learn): self.learn = learn 
    def after_fit(self, learn): self.learn = None

# %%
#|export
class RecorderCB(Callback):
    '''keep record of specific param.
    eg: rec = RecorderCB(lr=_lr)
    after every batch append
    '''
    def __init__(self, **d): self.d = d
    def before_fit(self, learn):
        self.recs = {k:[] for k in self.d}
        self.pg = learn.opt.param_groups[0]
    
    def after_batch(self, learn):
        if not learn.training: return
        for k,v in self.d.items():
            self.recs[k].append(v(self))

    def plot(self):
        for k,v in self.recs.items():
            plt.plot(v, label=k)
            plt.legend()
            plt.show()

# %%
def _lr(cb): return cb.pg['lr']

# %%
len(dls.train)
# Out:
# 59

# %%
tmax = 3 * len(dls.train)
sched = partial(lr_scheduler.CosineAnnealingLR, T_max=tmax)

# %%
set_seed(42)
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
rec = RecorderCB(lr=_lr)
xtra = [BatchSchedCB(sched),rec]
learn = TrainLearner(model, dls, F.cross_entropy, lr=2e-2, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.807</td>
#       <td>0.524</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.848</td>
#       <td>0.412</td>
# ...

# %%
rec.plot()

# %%
#|export
class EpochSchedCB(BaseSchedCB):
    def after_epoch(self, learn): self._step(learn)

# %%
sched = partial(lr_scheduler.CosineAnnealingLR, T_max=3)
set_seed(42)
xtra = [EpochSchedCB(sched),rec]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=2e-2, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.807</td>
#       <td>0.523</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.855</td>
#       <td>0.384</td>
# ...

# %%
rec.plot()

# %% [markdown]
# ### 1cycle training

# %% [markdown]
# [Paper](https://arxiv.org/abs/1803.09820) by Leslie Smith.

# %%
def _beta1(cb): return cb.pg['betas'][0]
rec = RecorderCB(lr=_lr, mom=_beta1)

# %%
set_seed(42)
lr,epochs = 6e-2,3
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched), rec]
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.769</td>
#       <td>0.650</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.846</td>
#       <td>0.436</td>
# ...

# %% [markdown]
# ### nb 12: notes:
#
#
#
# Optimizer API: needs to have a step, and zero gras
#
# Bsic Optimise step: p -= p.grad * self.lr
#
#
# These two are the same:
#
# Weight decay: weight -= lr*wd*weight
#
# L2 regularisation: weight.grad += wd*weight
#
# // becaues we essentially do
#
#
#
#
#
# Momentum: avg = beta*avg + (1-beta)*yi
#
# Use a moving avg. where beta decides how much of the previous avg to keep and how is the new one.
#
# Allows higher lr.
#
#
#
#
#
# RMS prop:
#
#     def opt_step(self, p):
#
#         if not hasattr(p, 'sqr_avg'): p.sqr_avg = p.grad**2
#
#         p.sqr_avg = p.sqr_avg*self.sqr_mom + p.grad**2*(1-self.sqr_mom)
#
#         p -= self.lr * p.grad/(p.sqr_avg.sqrt() + self.eps)
#
# The idea is to use the moving variance of the gradiants. If the variance is large than the lr is smaler, but if the variance is small, we can take a larger lr.
#
# Jeremy inits to the value of the first batch, because otherwise initially divid by eps, leading to very large lr.
#
#
#
# There are some architechtures that are better with momentum.
#
#
#
# The classic: adam: rmsm prop + momentum.
#
# Beta1 = momentum.
#
# Beta2 = rms momentum (the squares)
#
#         unbias_avg = p.avg / (1 - (self.beta1**(self.i+1))) # for the first few batches, when otherwise would be too close to 0.
#
# That's why we needed to know tha batch num.
#
#
# in pytorch, an optimiser has parameters, where it stores info about the layers which it needs for optimisation. formally theese are defined as the "state dict", where it stores the info on each layer, and other info such as storing momentum etc.
#
# an optimiser can have different settings for each layer, by deviding the parameters into groups.
#
#  scheduler:
#  adjust the lr over training.
#  it needs to know total number of steps that will be taken to correctly spread the schedule over all of training.
#
#  batch sceduler: spread over all batches (one scheduler step after every batch).
#  epoch scheduler: an optimiser step afer every epoch.
#
#  one cycle lr:
#  https://arxiv.org/pdf/1803.09820.pdf
#  found the good results from initial low lr, steadily increase then steadily decrease. spread over entire training.

# %%
rec.plot()

# %% [markdown]
# ## Export -

# %%
import nbdev; nbdev.nbdev_export()
